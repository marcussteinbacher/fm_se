# %%
import pandas as pd
import numpy as np
import scipy as sp
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import seaborn as sns
import ipywidgets as widgets
import requests
from bond import Bond, ILB
from cpi import RefCPI

sns.set()

# %% [markdown]
# ## Exploratory Data Analysis
# ### Overview

# %%
with pd.ExcelFile("data/can.xlsx") as xls:
    df_prices = pd.read_excel(xls,"Price",index_col=0,parse_dates=True)
    df_prices.columns = df_prices.columns.map(str)

with pd.ExcelFile("data/can.xlsx") as xls:
    df_info = pd.read_excel(xls,"Info",index_col=0)
    df_info.index = df_info.index.map(str)
    df_info.loc[:,"ISSUE DATE"] = pd.to_datetime(df_info["ISSUE DATE"],format="%d/%m/%Y")
    df_info.loc[:,"REDEMPTION DATE"] = pd.to_datetime(df_info["REDEMPTION DATE"],format="%d/%m/%y")

df_info.head()
#ISSUE DATE %d/%m%Y
#REDEMPTION DATE %d/%m%y
#COUPON DATES %d/%m
# Out:
#            ISIN CODE                                 NAME  COUPON  \
# Type
# 846111  CA135087VS05  CANADA 1995 4 1/4% 01/12/26 INDXLK.  7.6333
# 610286  CA135087WV25      CANADA 1999 4% 01/12/31 INDXLK.  6.9046
# 248402  CA135087XQ21      CANADA 2003 3% 01/12/36 INDXLK.  4.5947
# 97059Q  CA135087YK42      CANADA 2007 2% 01/12/41 INDXLK.  2.8366
# 5653HV  CA135087ZH04  CANADA 2010 1 1/2% 01/12/44 INDXLK.  2.0468
#
#         AMOUNT ISSUED COUPON DATES  INDEX LINKED COUP  COUPONS PER YEAR  \
# Type
# 846111      5250000.0  01/06,01/12               4.25                 2
# 610286      5800000.0  01/06,01/12               4.00                 2
# 248402      5850000.0  01/06,01/12               3.00                 2
# 97059Q      6550000.0  01/06,01/12               2.00                 2
# 5653HV      7700000.0  01/06,01/12               1.50                 2
#
#         1ST COUPON VALUE  OTHER YIELD  RED. YIELD CURRENCY  \
# Type
# 846111           2.06100        2.241         NaN       C$
# 610286           0.93150        2.129         NaN       C$
# 248402           1.43840        2.100         NaN       C$
# 97059Q           0.98630        2.122         NaN       C$
# 5653HV           0.00411        2.082         NaN       C$
#
#                  ISSUE DATE  MATURITY YEAR  START YEAR  ACTIVE  \
# Type
# 846111  1995-12-07 00:00:00           2026        1995  Active
# 610286  1999-03-08 00:00:00           2031        1999  Active
# 248402  2003-06-09 00:00:00           2036        2003  Active
# 97059Q  2007-06-04 00:00:00           2041        2007  Active
# 5653HV  2010-05-31 00:00:00           2044        2010  Active
#
#             REDEMPTION DATE  REF CPI BASE TYPE
# Type
# 846111  2026-12-01 00:00:00      87.82571  ILB
# 610286  2031-12-01 00:00:00      91.38249  ILB
# 248402  2036-12-01 00:00:00     102.99160  ILB
# 97059Q  2041-12-01 00:00:00     111.21849  ILB
# 5653HV  2044-12-01 00:00:00     115.60000  ILB

# %%
df_prices.describe()
# Out:
#             846111       610286       248402       97059Q       5653HV  \
# count  7101.000000  6388.000000  5291.000000  4254.000000  3472.000000
# mean    131.523548   140.659286   137.296017   125.957902   121.250779
# std      15.402941    17.718808    15.301789    14.941273    11.080769
# min      91.270000    97.190000    96.380000    83.407000    90.095000
# 25%     121.046000   126.686250   125.490000   113.618750   114.745000
# 50%     132.271000   145.215000   140.085000   130.043000   122.686500
# 75%     143.390000   152.328000   148.416500   137.485000   129.272250
# max     163.310000   177.060000   167.760000   151.729000   144.881000
#
#             787NK8       849UMH      645HW9       49199C       597973  \
# count  2560.000000  1644.000000  595.000000  5066.000000  3220.000000
# mean    118.027191    99.411933   83.899106    81.427279   123.895963
# std      11.938679    13.132456   14.599387    13.362473    12.519545
# min      85.543000    70.040000   62.547000    53.700000   100.012000
# 25%     112.396500    91.504750   72.561500    71.290500   111.268000
# 50%     118.104000    99.040500   77.984000    78.861500   127.878000
# 75%     126.102250   109.214500  100.148000    95.691000   132.350000
# max     144.432000   126.483000  113.357000    99.632000   144.160000
#
#             49197V       491985       491987       491989       49197U  \
# count  2042.000000  3089.000000  3350.000000  3611.000000  2651.000000
# mean     93.834697    87.900612    86.977643    86.875287    88.202239
# std       4.458731    10.957277    12.636888    14.121155     9.916209
# min      84.340000    62.530000    58.100000    55.100000    66.960000
# 25%      89.898500    82.770000    79.633100    78.403200    74.270000
# 50%      95.527000    92.682000    91.165500    88.909000    91.471000
# 75%      95.527000    95.736000    98.136500    98.442000    96.447000
# max     100.299000   100.645000   103.258000   110.655000    97.066000
#
#             491986       491970       491988       5771H1
# count  3220.000000  3174.000000  3481.000000  2434.000000
# mean     87.932411    86.273961    87.227865    90.442711
# std      11.801358    12.332432    13.382392     3.990232
# min      59.890000    59.560000    56.740000    79.110000
# 25%      81.808250    80.821250    79.170000    87.855000
# 50%      92.402000    92.423000    90.396000    92.762000
# 75%      97.954500    92.522000    98.467000    92.762000
# max     101.441000   101.604000   107.468000    94.478000

# %% [markdown]
# ## Historical Prices

# %%
fig, ax = plt.subplots()
sns.lineplot(df_prices,linewidth=0.5,ax=ax)
ax.axhline(y=100,linestyle="--",color="black",linewidth=0.5)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Maturities and reported Market Data

# %%
y = list(range(len(df_prices.columns)))
#available data
xmin = [min(df_prices[col].dropna().index) for col in df_prices.columns] 
xmax = [max(df_prices[col].dropna().index) for col in df_prices.columns]

#issue, maturity
issue_dates = [df_info.loc[bond,"ISSUE DATE"] for bond in df_prices.columns]
redem_dates = [df_info.loc[bond,"REDEMPTION DATE"] for bond in df_prices.columns]

fig, ax = plt.subplots()
plt.hlines(y=y,xmin=issue_dates,xmax=redem_dates, colors="black", linestyles="dashed", linewidths = .5)
plt.hlines(y=y,xmin=xmin,xmax=xmax,colors="tab:blue")
ax.axvline(x = max(df_prices.index),color="tab:orange",linewidth=0.75)
ax.set_yticks(list(range(len(df_prices.columns))))
ax.set_yticklabels(df_prices.columns)

for t in ax.yaxis.get_ticklabels():
    if df_info.loc[t.get_text(),"ACTIVE"] == "Active":
        t.set_color("tab:green")

plt.legend(handles=[mpatches.Patch(color="tab:green",label="Active"),
                    mpatches.Patch(color="tab:blue",label="Reported Prices"),
                    mlines.Line2D([0],[0],color="black",linestyle="dashed",linewidth=1, label="Total Runtime"),
                   mlines.Line2D([0],[1],color="tab:orange",label = "Horizon")])

#sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.show()

# %%
bond_dropdown = widgets.Dropdown(description="Bond",options=list(map(lambda t:t[::-1],list(df_info[["NAME"]].itertuples(name=None)))))

def plot_hist_prices(bond):
    fig,ax = plt.subplots()
    sns.lineplot(df_prices,x=df_prices.index,y=bond,ax=ax,label=bond,linewidth=.75)
    ax.axhline(y=100,linestyle="--",color="black",linewidth=1)
    ax.set_ylabel("")
    ax.set_xlabel("")
    plt.show()

    display(df_info.loc[bond,:])

out_0 = widgets.interactive_output(plot_hist_prices,{"bond":bond_dropdown})
display(bond_dropdown,out_0)
# Out:
# Dropdown(description='Bond', options=(('CANADA 1995 4 1/4% 01/12/26 INDXLK.', '846111'), ('CANADA 1999 4% 01/1…
# Output()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.axhline(y=100,linestyle="--",color="black",linewidth=1)
sns.violinplot(df_prices.reindex(df_prices.mean().sort_values(ascending=False).index, axis=1),ax = ax,legend=True)
plt.xticks(rotation=90)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ## Interest Rates
# TODO: [source](lökhf)

# %%
df_interest = pd.read_csv("data/chartered_bank_interest.csv",index_col="date",parse_dates=True)
df_interest_info  =  pd.read_csv("data/chartered_bank_interest_info.csv",index_col = "id")
df_interest_info.replace(np.nan,"",inplace=True)
df_interest_info["description"] = df_interest_info["label"]+" "+df_interest_info["description"]
df_interest_info = df_interest_info.loc[:,["description"]]

display(df_interest_info)

fig, ax = plt.subplots()
df_interest.plot(ax = ax,linewidth=0.75)
plt.xticks(rotation=45)
plt.show()
# Out:
#                                                 description
# id
# V80691311                                       Prime rate
# V80691333                      1-year Conventional mortgage
# V80691334                      3-year Conventional mortgage
# V80691335                      5-year Conventional mortgage
# V80691339         1-year Guaranteed investment certificates
# V80691340         3-year Guaranteed investment certificates
# V80691341         5-year Guaranteed investment certificates
# V80691336                       5-year personal fixed term
# V80691337  Daily Interest Savings (balances over $100,000)
# V80691338                   Non-Chequable Savings Deposits

# %% [markdown]
# ### Bond Market Prices vs. Interest Rates

# %%
interest_rate_dropdown = widgets.Dropdown(description="Interest",options=list(map(lambda t: t[::-1],df_interest_info[["description"]].itertuples(name=None))))

def plot_price_vs_interest_rate(bond,rate,**kwargs):
    min_date,max_date = min(df_prices[bond].dropna().index), max(df_prices[bond].dropna().index)
    df_interest_temp = df_interest.loc[min_date:max_date,:]
    
    with sns.axes_style("dark"):
        fig,ax = plt.subplots()
        ax1 = plt.twinx()
        
    sns.lineplot(df_prices,x=df_prices.index,y=bond,ax=ax,linewidth=.75)
    ax.axhline(y=100,linestyle="--",color="black",linewidth=.5)
    
    sns.lineplot(df_interest_temp,x=df_interest_temp.index,y=rate,ax=ax1,color="tab:red",linewidth=0.75)

    ax.set_ylabel("Bond Price",color="tab:blue")
    ax1.set_ylabel("Interest Rate",color="tab:red")
    ax.set_xlabel("")
    ax1.set_xlabel("")
    
    plt.show()
    display(df_info.loc[bond,:])


out_1 = widgets.interactive_output(plot_price_vs_interest_rate,{"bond":bond_dropdown,"rate":interest_rate_dropdown})
display(bond_dropdown,interest_rate_dropdown,out_1)
# Out:
# Dropdown(description='Bond', options=(('CANADA 1995 4 1/4% 01/12/26 INDXLK.', '846111'), ('CANADA 1999 4% 01/1…
# Dropdown(description='Interest', options=(('Prime rate ', 'V80691311'), ('1-year Conventional mortgage', 'V806…
# Output()

# %% [markdown]
# ## Cashflow Structure and Nominal Coupon Payments

# %%
coupons_only_checkbox = widgets.Checkbox(description = "Coupons only")
bond_dropdown_solo = widgets.Dropdown(description="Bond",options=list(map(lambda t:t[::-1],list(df_info[["NAME"]].itertuples(name=None)))))

def plot_cf(bond,coupons_only):

    issue_date = df_info.loc[bond,"ISSUE DATE"]
    redem_date = df_info.loc[bond,"REDEMPTION DATE"]
    freq = df_info.loc[bond,"COUPONS PER YEAR"]
    
    
    if freq == 2: #semi-annual: 01.06 und 01.12.
        dt_idx = pd.date_range(start=issue_date,end=redem_date,freq="AS-JUN").append(pd.date_range(start=issue_date,end=redem_date,freq="AS-DEC"))
        coupon = df_info.loc[bond,"INDEX LINKED COUP"]/freq
        df_coupon = pd.DataFrame(coupon,index=dt_idx,columns=["Coupon"])
    elif freq == 1: #not in the set
        pass
    else:
        df_coupon = pd.DataFrame(columns=["Coupon"])

    df_coupon.loc[issue_date,"Initial"] = -100
    df_coupon.loc[redem_date,"Redemption"] = 100
    df_cf = df_coupon.loc[df_coupon.index.sort_values(),:]

    fig, ax = plt.subplots(figsize=(12,4))
    
    if coupons_only:
        df_cf.plot(y="Coupon",kind="bar",ax=ax)
    else:
        df_cf.plot(kind="bar",ax=ax,stacked=True) 
    
    plt.xticks(rotation=90)
    
    plt.show()
    display(f"Issue Date: {issue_date.date()} | Redemption Date: {redem_date.date()}")
    with pd.option_context("display.max_rows", 8):
        display(df_cf)

out_2 = widgets.interactive_output(plot_cf,{"bond":bond_dropdown_solo,"coupons_only":coupons_only_checkbox})
display(bond_dropdown_solo,coupons_only_checkbox,out_2)
# Out:
# Dropdown(description='Bond', options=(('CANADA 1995 4 1/4% 01/12/26 INDXLK.', '846111'), ('CANADA 1999 4% 01/1…
# Checkbox(value=False, description='Coupons only')
# Output()

# %% [markdown]
# ## CPI - Base CPI - Index Ratio
# Calculation based upon: All-items Consumer Price Index for Canada, not seasonally
# adjusted, as published by Statistics Canada. <br>
# $$Ref CPI_{07/12/2010}=CPI_{09/2010}+\frac{7-1}{31}\big( CPI_{10/2012} - CPI_{09/2010} \big)$$
# $$IR_t = \frac{Ref CPI_{t}}{Ref CPI_{\tau}}$$
# Where $t$ is a specific date and $\tau$ is the issue date of the bond. <br>
# >INFO: Claculation is tested and precise for the Dates t but shows minimal deviation for base (=issue) dates; Thus, for non-strip bonds the reference index values from Bank of Canada, Index Ratios can be used.
# >
# TODO [source](kljgdfg)

# %%
ref_cpi = RefCPI()
ref_cpi.df.head()
# Out:
#                GEO           DGUID Products and product groups       UOM  \
# REF_DATE
# 1991-01-01  Canada  2016A000011124                   All-items  2002=100
# 1991-02-01  Canada  2016A000011124                   All-items  2002=100
# 1991-03-01  Canada  2016A000011124                   All-items  2002=100
# 1991-04-01  Canada  2016A000011124                   All-items  2002=100
# 1991-05-01  Canada  2016A000011124                   All-items  2002=100
#
#             UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  COORDINATE  VALUE  \
# REF_DATE
# 1991-01-01      17         units          0  v41690973         2.2   82.0
# 1991-02-01      17         units          0  v41690973         2.2   82.0
# 1991-03-01      17         units          0  v41690973         2.2   82.3
# 1991-04-01      17         units          0  v41690973         2.2   82.3
# 1991-05-01      17         units          0  v41690973         2.2   82.7
#
#             STATUS  SYMBOL  TERMINATED  DECIMALS
# REF_DATE
# 1991-01-01     NaN     NaN         NaN         1
# 1991-02-01     NaN     NaN         NaN         1
# 1991-03-01     NaN     NaN         NaN         1
# 1991-04-01     NaN     NaN         NaN         1
# 1991-05-01     NaN     NaN         NaN         1

# %%
sns.lineplot(data=ref_cpi.df,x="REF_DATE",y="VALUE")
plt.show()

# %% [markdown]
# ### Deviation Ref CPI Calculation - BoC Reporting
# Deviation for issue dates < 2010 <br>
# TODO [source](köugsagf)

# %%
def show_base_cpi_deviation(bond):
    print(bond, " ",df_info.loc[bond,"NAME"])
    
    base = df_info.loc[bond,"ISSUE DATE"]
    boc_cpi = df_info.loc[bond,"REF CPI BASE"]
    
    print("Issue Date: ",base)
    print("Calculation: ", ref_cpi.ref_cpi(base)) 
    print("Bank of Canada: ", boc_cpi)

out_3 = widgets.interactive_output(show_base_cpi_deviation,{"bond":bond_dropdown})

display(bond_dropdown, out_3)
# Out:
# Dropdown(description='Bond', options=(('CANADA 1995 4 1/4% 01/12/26 INDXLK.', '846111'), ('CANADA 1999 4% 01/1…
# Output()

# %%
issue_dates = [df_info.loc[bond,"ISSUE DATE"] for bond in df_prices.columns]
cpi_reals = [df_info.loc[bond,"REF CPI BASE"] for bond in df_prices.columns]
cpi_calcs = [ref_cpi.ref_cpi(issue_date) for issue_date in issue_dates]
diff = [abs(a-b)/a for a,b in zip(cpi_reals,cpi_calcs)]
labels = [n+":"+d.strftime("%Y") for n,d in zip(df_prices.columns,issue_dates)]

with sns.axes_style("dark"):
    fig,ax = plt.subplots()
    ax1 = plt.twinx()

ax.bar(x=range(len(df_prices.columns)),height=cpi_reals,align="edge",width=0.35,color="tab:blue",label="Reported Ref CPI base")
ax.bar(x=range(len(df_prices.columns)),height=cpi_calcs,align="edge",width=-0.35,color="tab:orange",label="Calculated Ref CPI base")

ax1.stem(range(len(df_prices.columns)),diff,linefmt="black",markerfmt="o",basefmt="black",label="Deviation")

ax.set_ylim(0,150)
ax1.set_ylim(0,0.001)

ax.set_xticks(range(len(df_prices.columns)),labels=labels,rotation=90)
ax.set_ylabel("Ref CPI")
ax1.set_ylabel("Relative Deviation")

ax.legend(loc=(0.5,1))
ax1.legend()
plt.show()

# %% [markdown]
# # Bond Evaluation

# %%
df_info.loc["597973",:]
# Out:
# ISIN CODE                                   CA135087UL60
# NAME                 CANADA 1991 4 1/4% 01/12/21 INDXLK.
# COUPON                                            7.3104
# AMOUNT ISSUED                                  5175000.0
# COUPON DATES                                 01/06,01/12
# INDEX LINKED COUP                                   4.25
# COUPONS PER YEAR                                       2
# 1ST COUPON VALUE                                   2.026
# OTHER YIELD                                       -3.635
# RED. YIELD                                           NaN
# CURRENCY                                              C$
# ISSUE DATE                           1991-12-10 00:00:00
# MATURITY YEAR                                       2021
# START YEAR                                          1991
# ACTIVE                                              Dead
# REDEMPTION DATE                      2021-12-01 00:00:00
# REF CPI BASE                                    83.07713
# TYPE                                                 ILB
# Name: 597973, dtype: object

# %% [markdown]
# ### Evaluation as Nominal Bond - Example
# Checked back and verified with [Vindeep](https://vindeep.com/Corporate/BondYTMCalculator.aspx)
#
# #### Coupon Bond

# %%
bnd_id = "597973"
name = df_info.loc[bnd_id,"NAME"]
issue_date = df_info.loc[bnd_id,"ISSUE DATE"]
redem_date = df_info.loc[bnd_id,"REDEMPTION DATE"]
prices = df_prices[bnd_id]
coupon = df_info.loc[bnd_id,"INDEX LINKED COUP"]

bond = Bond(bnd_id,name,issue_date,redem_date,prices,coupon,coupon_freq=["AS-DEC","AS-JUN"])
bond
# Out:
# 597973 | CANADA 1991 4 1/4% 01/12/21 INDXLK. | 4.25
# 10/12/91 - 01/12/21

# %%
eval_date = pd.Timestamp("2018-07-23")
cfs = bond.cashflows(eval_date,dirty=True,daycount="act/365")
cfs
# Out:
# 2018-07-23   -113.487479
# 2018-12-01      2.125000
# 2019-06-01      2.125000
# 2019-12-01      2.125000
# 2020-06-01      2.125000
# 2020-12-01      2.125000
# 2021-06-01      2.125000
# 2021-12-01    102.125000
# dtype: float64

# %%
bond.ytm(eval_date)
# Out:
# 0.0038451369790563645

# %% [markdown]
# **Info** If no market price is reported for a specific evaluation_date, one can force a cashflow: The missing price will simply be subsituted by the par value (= 100). <br>
# Helpful to print the cashflow structure of a nominal bond without pricing information.

# %%
bond.cashflows(issue_date,force=True,dirty=False)
# Out:
# No market price is reported for the evaluation date 1991-12-10.
# Assume par value for the evaluation date 1991-12-10!
# 1991-12-10   -100.000
# 1992-06-01      2.125
# 1992-12-01      2.125
# 1993-06-01      2.125
# 1993-12-01      2.125
#                ...
# 2019-12-01      2.125
# 2020-06-01      2.125
# 2020-12-01      2.125
# 2021-06-01      2.125
# 2021-12-01    102.125
# Length: 61, dtype: float64

# %% [markdown]
# Inspecting the date differences in the calculation of the internal rate of return (yield):

# %%
df = pd.DataFrame(cfs,columns=["cf"])
df["dd"] = (cfs.index-eval_date).days
fig,ax = plt.subplots()
sns.barplot(df,x=df.index,y="cf",ax=ax)
plt.xticks(rotation=90)
plt.xlabel("")
display(df)
plt.show()
# Out:
#                     cf    dd
# 2018-07-23 -113.487479     0
# 2018-12-01    2.125000   131
# 2019-06-01    2.125000   313
# 2019-12-01    2.125000   496
# 2020-06-01    2.125000   679
# 2020-12-01    2.125000   862
# 2021-06-01    2.125000  1044
# 2021-12-01  102.125000  1227

# %% [markdown]
# #### Zero Bond
# `Coupon = 0` <br>
# `Coupon Dates = []` <br>
# `dirty`: No accrued interest - no dirty price!

# %%
bnd_id = "597973"
name = df_info.loc[bnd_id,"NAME"]
issue_date = df_info.loc[bnd_id,"ISSUE DATE"]
redem_date = df_info.loc[bnd_id,"REDEMPTION DATE"]
prices = df_prices[bnd_id]
coupon = 0

zero_bond = Bond(bnd_id, name, issue_date, redem_date, prices, coupon)

# %%
zero_bond.cashflows(eval_date, dirty=False, force=False)
# Out:
# 2018-07-23   -112.882
# 2021-12-01    100.000
# dtype: float64

# %%
zero_bond.ytm(eval_date)
# Out:
# -0.035403799362747734

# %% [markdown]
# ## Evaluation of ILBs - Example
# Entweder ref_cpi_base übergeben, ansonsten wird es berechnet für das
# issue_date.
# ### Cashflows

# %%
ilb = ILB(bnd_id,name,issue_date,redem_date,prices,4.25,coupon_freq=["AS-DEC","AS-JUN"],ref_cpi_base = 83.07713)
cfs_ilb = ilb.cashflows(eval_date)
cfs_ilb
# Out:
# 2018-07-23   -113.487479
# 2018-12-01      3.419869
# 2019-06-01      3.463346
# 2019-12-01      3.483810
# 2020-06-01      3.494053
# 2020-12-01      3.501724
# 2021-06-01      3.570786
# 2021-12-01    175.664191
# dtype: float64

# %% [markdown]
# ### Index Ratios & Ref CPI Base
# vgl. BoC (`en_inratio21-12.pdf`): 4.25% 1 Dec. 2021 Ref CPI Base: 83.07713 | IR für 1 Dec. 2021: 1.72009 <br>
# **Frage: Auch den negativen CF (Marktpreis) mit einem IR skalieren?**

# %%
ilb.index_ratios, ilb.ref_cpi_base
# Out:
# (2018-07-23    1.00000
#  2018-12-01    1.60935
#  2019-06-01    1.62981
#  2019-12-01    1.63944
#  2020-06-01    1.64426
#  2020-12-01    1.64787
#  2021-06-01    1.68037
#  2021-12-01    1.72009
#  dtype: float64,
#  83.07713)

# %%
ilb.ytm(eval_date)
# Out:
# 0.19123876142392818

# %%
ilb
# Out:
# 597973 | CANADA 1991 4 1/4% 01/12/21 INDXLK. | 4.25
# 10/12/91 - 01/12/21

# %% [markdown]
# ### CHECK: YTM

# %%
import scipy as sp

def pv(r):
    s = 0
    for cf, dd in zip(df["cf"].values,df["dd"].values):
        s += cf/(1+r)**(dd/365)
    return s
display(df)
sp.optimize.newton(pv,4.25/100)
# Out:
#                     cf    dd
# 2018-07-23 -113.487479     0
# 2018-12-01    2.125000   131
# 2019-06-01    2.125000   313
# 2019-12-01    2.125000   496
# 2020-06-01    2.125000   679
# 2020-12-01    2.125000   862
# 2021-06-01    2.125000  1044
# 2021-12-01  102.125000  1227
# 0.0038451369790610222

# %% [markdown]
# # Yield Curves
# Daily yield to maturity for a given bond

# %%
bnd_id = "597973"
name = df_info.loc[bnd_id,"NAME"]
issue_date = df_info.loc[bnd_id,"ISSUE DATE"]
redem_date = df_info.loc[bnd_id,"REDEMPTION DATE"]
prices = df_prices[bnd_id]
coupon = df_info.loc[bnd_id,"INDEX LINKED COUP"]

bond_alt = ILB(bnd_id,name,issue_date,redem_date,prices,coupon,coupon_freq=["AS-JUN","AS-DEC"])
bond_alt
# Out:
# 597973 | CANADA 1991 4 1/4% 01/12/21 INDXLK. | 4.25
# 10/12/91 - 01/12/21

# %%
bond_alt.cashflows(pd.Timestamp("2009-08-05"))
# Out:
# 2009-08-05   -129.256849
# 2009-12-01      2.934094
# 2010-06-01      2.957108
# 2010-12-01      2.990364
# 2011-06-01      3.054326
# 2011-12-01      3.085011
# 2012-06-01      3.113146
# 2012-12-01      3.120818
# 2013-06-01      3.143852
# 2013-12-01      3.154074
# 2014-06-01      3.192451
# 2014-12-01      3.218036
# 2015-06-01      3.230829
# 2015-12-01      3.251292
# 2016-06-01      3.271756
# 2016-12-01      3.294770
# 2017-06-01      3.322905
# 2017-12-01      3.345940
# 2018-06-01      3.399660
# 2018-12-01      3.420124
# 2019-06-01      3.463601
# 2019-12-01      3.484065
# 2020-06-01      3.494307
# 2020-12-01      3.501979
# 2021-06-01      3.571041
# 2021-12-01    175.677468
# dtype: float64

# %%
bond_alt.ytm(pd.Timestamp("2009-08-05"))
# Out:
# 0.06955412976382104

# %%
yield_curve = bond_alt.yield_curve() #Alle generieren und in Datei speichern
# Out:
# 597973 :  2021-11-30 :  Failed to converge after 50 iterations, value is 3.5127765689200895e+71.
# 597973 :  2021-12-01 :  Tolerance of 0.0001 reached. Failed to converge after 1 iterations, value is 0.0001.

# %%
sns.lineplot(yield_curve,x=yield_curve.index,y="YTM")
plt.show()
max_y = yield_curve["YTM"].max()
mask = yield_curve["YTM"] == max_y

yc_clean = yield_curve.loc[:"2020-01-01",:]#yield_curve[~mask]

sns.lineplot(yc_clean,x=yc_clean.index,y="YTM")
plt.show()

# %% [markdown]
# ### Example: Spline Fitting
# **Info:** ytm very sensitive to missing(?) data/ constant prices: e.g. `CPN STRIP 01/12/21`, `CPN STRIP 01/12/19`

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import SplineTransformer
from sklearn.pipeline import Pipeline
import pickle

with open("export/yield_curves.pickle","rb") as f:
    data = pickle.load(f)

# %%
def plot_yield_curve(bond_alt):
    yield_curve = data[bond_alt].dropna()
    df_sorted = yield_curve.sort_values(by="TTM")
    X,y = df_sorted[["TTM"]], df_sorted["YTM"]
    model = Pipeline([
        ('poly', SplineTransformer(n_knots=7,degree=3)), #Spline with N=9
        ('linear', LinearRegression())
    ])
    model.fit(X,y)
    X_test = np.linspace(X.min(),X.max(),100).reshape(-1,1)
    y_pred = model.predict(X_test)

    fig,axs = plt.subplots(nrows=2,height_ratios=(3,2))
    sns.lineplot(yield_curve,x="TTM",y="YTM",linewidth=1,ax=axs[0],color="tab:grey",label="YTM")
    
    sns.lineplot(x=X_test.flatten(),y=y_pred,ax=axs[0],linewidth=0.8,linestyle="--",color="tab:pink")
    sns.lineplot(df_prices[bond_alt],ax=axs[1],label="Price")
    axs[0].set_title(bond_alt)
    plt.show()

out4 = widgets.interactive_output(plot_yield_curve,{"bond_alt":bond_dropdown})
display(bond_dropdown,out4)
# Out:
# Dropdown(description='Bond', options=(('CANADA 1995 4 1/4% 01/12/26 INDXLK.', '846111'), ('CANADA 1999 4% 01/1…
# Output()

# %% [markdown]
# ## Missing Market Data Handling

# %% [raw]
# ddiffs = []
# for bond in df_prices.columns:
#     first_date = df_prices[bond].dropna().index[0]
#     last_date = df_prices[bond].dropna().index[-1]
#
#     start_date = pd.to_datetime(dt.datetime.strftime(df_info.loc[bond,"ISSUE DATE"],"%d/%m/%Y"))
#     end_date = pd.to_datetime(dt.datetime.strftime(df_info.loc[bond,"REDEMPTION DATE"],"%d/%m/%y"))
#
#     print(bond, df_info.loc[bond,"NAME"], df_info.loc[bond,"ACTIVE"])
#     print("first date: ", first_date, "issue date: ",start_date)
#     print("last date: ", last_date, "redemption date: ", end_date)
#     print()

# %% [markdown]
# # Bank of Canada API

# %%
import requests
import json
base_url = "https://www.bankofcanada.ca/valet/"
r = requests.get(base_url+"observations/INDEX_RATIO_2021/csv")

# %%
print(r.text)
# Out:
# ﻿"TERMS AND CONDITIONS"
# "https://www.bankofcanada.ca/terms/"
#
# "SERIES"
# "id","label","description"
# "INDEX_RATIO_2021","Real Return Bonds - Index ratio 2021","Real Return Bonds - Index ratio 2021"
#
# "OBSERVATIONS"
# "date","INDEX_RATIO_2021"
# "2021-12-01","1.72009"
# "2021-12-02","1.72048"
# "2021-12-03","1.72086"
# "2021-12-04","1.72125"
# "2021-12-05","1.72164"
# "2021-12-06","1.72203"
# "2021-12-07","1.72242"
# "2021-12-08","1.72281"
# "2021-12-09","1.72319"
# "2021-12-10","1.72358"
# "2021-12-11","1.72397"
# "2021-12-12","1.72436"
# "2021-12-13","1.72475"
# "2021-12-14","1.72514"
# "2021-12-15","1.72552"
# "2021-12-16","1.72591"
# "2021-12-17","1.72630"
# "2021-12-18","1.72669"
# "2021-12-19","1.72708"
# "2021-12-20","1.72747"
# "2021-12-21","1.72785"
# "2021-12-22","1.72824"
# "2021-12-23","1.72863"
# "2021-12-24","1.72902"
# "2021-12-25","1.72941"
# "2021-12-26","1.72980"
# "2021-12-27","1.73018"
# "2021-12-28","1.73057"
# "2021-12-29","1.73096"
# "2021-12-30","1.73135"
# "2021-12-31","1.73174"
# "2022-01-01","1.73213"
# "2022-01-02","1.73224"
# "2022-01-03","1.73236"
# "2022-01-04","1.73247"
# "2022-01-05","1.73259"
# "2022-01-06","1.73271"
# "2022-01-07","1.73282"
# "2022-01-08","1.73294"
# "2022-01-09","1.73306"
# "2022-01-10","1.73317"
# "2022-01-11","1.73329"
# "2022-01-12","1.73341"
# "2022-01-13","1.73352"
# "2022-01-14","1.73364"
# "2022-01-15","1.73376"
# "2022-01-16","1.73387"
# "2022-01-17","1.73399"
# "2022-01-18","1.73411"
# "2022-01-19","1.73422"
# "2022-01-20","1.73434"
# "2022-01-21","1.73446"
# "2022-01-22","1.73457"
# "2022-01-23","1.73469"
# "2022-01-24","1.73480"
# "2022-01-25","1.73492"
# "2022-01-26","1.73504"
# "2022-01-27","1.73515"
# "2022-01-28","1.73527"
# "2022-01-29","1.73539"
# "2022-01-30","1.73550"
# "2022-01-31","1.73562"
# "2022-02-01","1.73574"

#   {'d': '2021-08-01', 'V41690973': {'v': '142.6'}},
#   {'d': '2021-09-01', 'V41690973': {'v': '142.9'}},
#   {'d': '2021-10-01', 'V41690973': {'v': '143.9'}},
#   {'d': '2021-11-01', 'V41690973': {'v': '144.2'}},
#   {'d': '2021-12-01', 'V41690973': {'v': '144.0'}},
#   {'d': '2022-01-01', 'V41690973': {'v': '145.3'}},
#   {'d': '2022-02-01', 'V41690973': {'v': '146.8'}},
#   {'d': '2022-03-01', 'V41690973': {'v': '148.9'}},
#   {'d': '2022-04-01', 'V41690973': {'v': '149.8'}},
#   {'d': '2022-05-01', 'V41690973': {'v': '151.9'}},
#   {'d': '2022-06-01', 'V41690973': {'v': '152.9'}},
#   {'d': '2022-07-01', 'V41690973': {'v': '153.1'}},
#   {'d': '2022-08-01', 'V41690973': {'v': '152.6'}},
#   {'d': '2022-09-01', 'V41690973': {'v': '152.7'}},
#   {'d': '2022-10-01', 'V41690973': {'v': '153.8'}},
#   {'d': '2022-11-01', 'V41690973': {'v': '154.0'}},
#   {'d': '2022-12-01', 'V41690973': {'v': '153.1'}},
#   {'d': '2023-01-01', 'V41690973': {'v': '153.9'}},
#   {'d': '2023-02-01', 'V41690973': {'v': '154.5'}},
#   {'d': '2023-03-01', 'V41690973': {'v': '155.3'}},
#   {'d': '2023-04-01', 'V41690973': {'v': '156.4'}},
#   {'d': '2023-05-01', 'V41690973': {'v': '157.0'}},
#   {'d': '2023-06-01', 'V41690973': {'v': '157.2'}},
#   {'d': '2023-07-01', 'V41690973': {'v': '158.1'}},
#   {'d': '2023-08-01', 'V41690973': {'v': '158.7'}},
#   {'d': '2023-09-01', 'V41690973': {'v': '158.5'}}]}

# %%
r = requests.get("https://www.bankofcanada.ca/valet/lists/groups")
print(r.text)
# Out:
# {
#     "terms": {
#         "url": "https://www.bankofcanada.ca/terms/"
#     },
#     "groups": {
#         "sdp-2012-8": {
#             "label": "Staff Discussion Paper 2012-8",
#             "link": "https://www.bankofcanada.ca/valet/groups/sdp-2012-8",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nNote from the author(s):\nThe BOS underlying indicator is re-estimated every quarter following the release of the Business Outlook Survey (results are available on the Bank website). As such, the entire time series is revised after every release.  The date field refers to the first day of the quarter where the BOS underlying indicator is estimated. For example, 01/04/2016 refers to the 2016Q2 estimate, which is available roughly one week after the end of the quarter (e.g. mid-July 2016).\nContact person:\nLise Pichette (lpichette@bank-banque-canada.ca)"
#         },
#         "swp-2012-37": {
#             "label": "Staff Working Paper 2012-37",
#             "link": "https://www.bankofcanada.ca/valet/groups/swp-2012-37",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nStatistics Canada, Consensus Economics\nContact person:\nBruno Fenou (BFeunou@bank-banque-canada.ca)"
#         },
#         "swp-2015-46": {
#             "label": "Staff Working Paper 2015-46",
#             "link": "https://www.bankofcanada.ca/valet/groups/swp-2015-46",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nCRSP Fixed Income Database\nContact person:\nJean-Sébastien Fontaine (jsfontaine@bank-banque-canada.ca)"
#         },
#         "swp-2013-42": {
#             "label": "Staff Working Paper 2013-42",
#             "link": "https://www.bankofcanada.ca/valet/groups/swp-2013-42",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nStatistics Canada\nNote from the author(s):\nThe date field shows the state of real economic activity in real time and is based on data available on that date.\nContact person:\nGitanjali Kumar (gkumar@bank-banque-canada.ca)"
#         },
#         "sdp-2014-3": {
#             "label": "Staff Discussion Paper 2014-3",
#             "link": "https://www.bankofcanada.ca/valet/groups/sdp-2014-3",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nHaver Analytics/Markit, Haver Analytics/Eurostat, Haver Analytics/European Commission, Haver Analytics/CEPR, Haver Analytics/European Central Bank, Haver Analytics/Cabinet Office of Japan, Haver Analytics/METI, Haver Analytics/JAMA\nNote from the author(s):\nThe estimates provided are the real-time forecasts for GDP growth as of the first day of each month. Based on a re-evaluation of the forecast errors in the spring of 2016, the MIDAS forecast for Japan is now based on the average forecast from the following indicators: (1) PMI (average of composite output, new orders, employment, and backlogs of work), (2) the Shoko-Chukin Survey (average of small/medium businesses finished goods inventory and production capacity), (3) the Cabinet Office consumption index, (4) retail sales, and (5) industrial production. \nContact person: \nMaxime Leboeuf (mleboeuf@bank-banque-canada.ca)"
#         },
#         "sdp-2016-5": {
#             "label": "Staff Discussion Paper 2016-5",
#             "link": "https://www.bankofcanada.ca/valet/groups/sdp-2016-5",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nConsensus Economics, Haver Analytics/Bank of Japan, Haver Analytics/Federal Reserve Board, Haver Analytics/European Central Bank, Haver Analytics/OECD, Bloomberg\nNote from the author(s):\nThe model is re-estimated every time new data is available and the data provided is the resulting in-sample fit. As such, all data series provided are revised when new data is available.\nContact person:\nMaxime Leboeuf (mleboeuf@bank-banque-canada.ca)"
#         },
#         "swp-2013-37": {
#             "label": "Staff Working Paper 2013-37",
#             "link": "https://www.bankofcanada.ca/valet/groups/swp-2013-37",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nMontréal Exchange, Thomson Reuters\nContact person:\nBo Young Chang (bchang@bank-banque-canada.ca)"
#         },
#         "bos": {
#             "label": "Business Outlook Survey",
#             "link": "https://www.bankofcanada.ca/valet/groups/bos",
#             "description": "A summary of interviews conducted by the Bank's regional offices with the senior management of about 100 firms, selected in accordance with the composition of Canada's gross domestic product.\nThe survey's purpose is to gather the perspectives of these businesses on topics of interest to the Bank of Canada (such as demand and capacity pressures) and their forward-looking views on economic activity."
#         },
#         "FX_RATES_RECIPROCAL": {
#             "label": "Daily reciprocal exchange rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/FX_RATES_RECIPROCAL",
#             "description": "Daily average reciprocal exchange rates - published once each business day by 16:30 ET. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "FX_RATES_DAILY": {
#             "label": "Daily exchange rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/FX_RATES_DAILY",
#             "description": "Daily average exchange rates - published once each business day by 16:30 ET. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "FX_RATES_MONTHLY": {
#             "label": "Monthly exchange rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/FX_RATES_MONTHLY",
#             "description": "Monthly average exchange rates - published by 16:30 ET on the last business day of each month. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "FX_RATES_ANNUAL": {
#             "label": "Annual exchange rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/FX_RATES_ANNUAL",
#             "description": "Annual average exchange rates - published by 16:30 ET on the last business day of each year. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "BCPI_WEEKLY": {
#             "label": "Weekly BCPI",
#             "link": "https://www.bankofcanada.ca/valet/groups/BCPI_WEEKLY",
#             "description": "Weekly Bank of Canada commodity price index."
#         },
#         "BCPI_MONTHLY": {
#             "label": "Monthly BCPI",
#             "link": "https://www.bankofcanada.ca/valet/groups/BCPI_MONTHLY",
#             "description": "Monthly Bank of Canada commodity price index."
#         },
#         "BCPI_ANNUAL": {
#             "label": "Annual BCPI",
#             "link": "https://www.bankofcanada.ca/valet/groups/BCPI_ANNUAL",
#             "description": "Annual Bank of Canada commodity price index."
#         },
#         "BCPI_WEIGHTS": {
#             "label": "BCPI Weights",
#             "link": "https://www.bankofcanada.ca/valet/groups/BCPI_WEIGHTS",
#             "description": "BCPI Weights"
#         },
#         "LEGACY_NOON_RATES": {
#             "label": "Legacy Noon Rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/LEGACY_NOON_RATES",
#             "description": "The legacy exchange rates were last updated 28 April 2017 and will not be updated in future. Exchange rates are expressed as 1 unit of the foreign currency converted into Canadian dollars. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "LEGACY_ClOSING_RATES": {
#             "label": "Legacy Closing Rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/LEGACY_ClOSING_RATES",
#             "description": "The legacy exchange rates were last updated 28 April 2017 and will not be updated in future. Exchange rates are expressed as 1 unit of the foreign currency converted into Canadian dollars. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "LEGACY_MONTHLY_RATES": {
#             "label": "Legacy Monthly Average Rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/LEGACY_MONTHLY_RATES",
#             "description": "The legacy exchange rates were last updated 28 April 2017 and will not be updated in future. Exchange rates are expressed as 1 unit of the foreign currency converted into Canadian dollars. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "LEGACY_ANNUAL_RATES": {
#             "label": "Legacy Annual Average Rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/LEGACY_ANNUAL_RATES",
#             "description": "The legacy exchange rates were last updated 28 April 2017 and will not be updated in future. Exchange rates are expressed as 1 unit of the foreign currency converted into Canadian dollars. All Bank of Canada exchange rates are indicative rates only."
#         },
#         "SAN-2017-2": {
#             "label": "Staff Analytical Note 2017-2",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN-2017-2",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nSources:\nBloomberg Finance L.P., Bloomberg Finance L.P./Bank of America Merrill Lynch\nNote from the author(s):\nThe model is re-estimated every time new data is available and the data provided is the resulting in-sample fit. As such, all data series provided are revised when new data is available.\nContact person:\nMaxime Leboeuf (mleboeuf@bank-banque-canada.ca)"
#         },
#         "RRB_INDEX_RATIO": {
#             "label": "Real Return Bonds - Index ratios",
#             "link": "https://www.bankofcanada.ca/valet/groups/RRB_INDEX_RATIO",
#             "description": "Real Return Bonds - Index ratios"
#         },
#         "FSR-2016-DECEMBER": {
#             "label": "December 2016 FSR",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER",
#             "description": "December 2016 FSR"
#         },
#         "FSR-2016-DECEMBER-CHART-2": {
#             "label": "December 2016 FSR, Chart 2",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER-CHART-2",
#             "description": "December 2016 FSR, Chart 2"
#         },
#         "FSR-2016-DECEMBER-CHART-5": {
#             "label": "December 2016 FSR, Chart 5",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER-CHART-5",
#             "description": "December 2016 FSR, Chart 5"
#         },
#         "FSR-2016-DECEMBER-CHART-6": {
#             "label": "December 2016 FSR, Chart 6",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER-CHART-6",
#             "description": "December 2016 FSR, Chart 6"
#         },
#         "FSR-2016-DECEMBER-CHART-7": {
#             "label": "December 2016 FSR, Chart 7",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER-CHART-7",
#             "description": "December 2016 FSR, Chart 7"
#         },
#         "FSR-2016-DECEMBER-CHART-8": {
#             "label": "December 2016 FSR, Chart 8",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER-CHART-8",
#             "description": "December 2016 FSR, Chart 8"
#         },
#         "FSR-2016-DECEMBER-CHART-2A": {
#             "label": "December 2016 FSR, Chart 2A",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2016-DECEMBER-CHART-2A",
#             "description": "December 2016 FSR, Chart 2A"
#         },
#         "FSR-2017-JUNE-CHART-2": {
#             "label": "June 2017 FSR, Chart 2",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-2",
#             "description": "June 2017 FSR, Chart 2"
#         },
#         "FSR-2017-JUNE-CHART-3": {
#             "label": "June 2017 FSR, Chart 3",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-3",
#             "description": "June 2017 FSR, Chart 3"
#         },
#         "FSR-2017-JUNE-CHART-4": {
#             "label": "June 2017 FSR, Chart 4",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-4",
#             "description": "June 2017 FSR, Chart 4"
#         },
#         "FSR-2017-JUNE-CHART-5": {
#             "label": "June 2017 FSR, Chart 5",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-5",
#             "description": "June 2017 FSR, Chart 5"
#         },
#         "FSR-2017-JUNE-CHART-6": {
#             "label": "June 2017 FSR, Chart 6",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-6",
#             "description": "June 2017 FSR, Chart 6"
#         },
#         "FSR-2017-JUNE-CHART-7": {
#             "label": "June 2017 FSR, Chart 7",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-7",
#             "description": "June 2017 FSR, Chart 7"
#         },
#         "FSR-2017-JUNE-CHART-8": {
#             "label": "June 2017 FSR, Chart 8",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE-CHART-8",
#             "description": "June 2017 FSR, Chart 8"
#         },
#         "FSR-2017-JUNE": {
#             "label": "June 2017 FSR",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-JUNE",
#             "description": "June 2017 FSR"
#         },
#         "CEER_DAILY": {
#             "label": "CEER Daily",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_DAILY",
#             "description": "Daily Nominal Canadian Effective Exchange Rates"
#         },
#         "CEER_MONTHLY_NOMINAL": {
#             "label": "CEER Monthly Nominal",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_MONTHLY_NOMINAL",
#             "description": "Monthly Nominal Canadian Effective Exchange Rates"
#         },
#         "CEER_MONTHLY_REAL": {
#             "label": "CEER Monthly Real",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_MONTHLY_REAL",
#             "description": "Monthly Real Canadian Effective Exchange Rates"
#         },
#         "CEER_TOTAL_WEIGHTS": {
#             "label": "CEER Total Weights",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_TOTAL_WEIGHTS",
#             "description": "Canadian Effective Exchange Rate Total Weights"
#         },
#         "CEER_EXPORT_WEIGHTS": {
#             "label": "CEER Export Weights",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_EXPORT_WEIGHTS",
#             "description": "Canadian Effective Exchange Rate Export Weights"
#         },
#         "CEER_IMPORT_WEIGHTS": {
#             "label": "CEER Import Weights",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_IMPORT_WEIGHTS",
#             "description": "Canadian Effective Exchange Rate Import Weights"
#         },
#         "CEER_THIRD-MARKET_COMPETITION_WEIGHTS": {
#             "label": "CEER Third-Market Competition Weights",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER_THIRD-MARKET_COMPETITION_WEIGHTS",
#             "description": "Canadian Effective Exchange Rate Third-Market Competition Weights"
#         },
#         "CEER": {
#             "label": "CEER",
#             "link": "https://www.bankofcanada.ca/valet/groups/CEER",
#             "description": "CEER"
#         },
#         "B1_MONTHLY": {
#             "label": "Bank of Canada assets and liabilities: Month-end",
#             "link": "https://www.bankofcanada.ca/valet/groups/B1_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "B2_WEEKLY": {
#             "label": "Bank of Canada assets and liabilities: Weekly",
#             "link": "https://www.bankofcanada.ca/valet/groups/B2_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "B3_MONTHLY": {
#             "label": "Positions of members of Payments Canada with the Bank of Canada",
#             "link": "https://www.bankofcanada.ca/valet/groups/B3_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "B3_WEEKLY": {
#             "label": "Positions of members of Payments Canada with the Bank of Canada",
#             "link": "https://www.bankofcanada.ca/valet/groups/B3_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "G4_WEEKLY": {
#             "label": "Government of Canada direct securities and loans: Distribution of holdings",
#             "link": "https://www.bankofcanada.ca/valet/groups/G4_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars (par value)"
#         },
#         "G4_MONTHLY": {
#             "label": "Government of Canada direct securities and loans: Distribution of holdings",
#             "link": "https://www.bankofcanada.ca/valet/groups/G4_MONTHLY",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "GOCCADDEP_WEEKLY": {
#             "label": "Government of Canada Canadian Dollar Deposits",
#             "link": "https://www.bankofcanada.ca/valet/groups/GOCCADDEP_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "F11_WEEKLY": {
#             "label": "Historical money market trading by type of security",
#             "link": "https://www.bankofcanada.ca/valet/groups/F11_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "F14_WEEKLY": {
#             "label": "Historical strip bond trading and repos by type of security",
#             "link": "https://www.bankofcanada.ca/valet/groups/F14_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "C1_MONTHLY": {
#             "label": "Chartered bank selected assets: Month-end",
#             "link": "https://www.bankofcanada.ca/valet/groups/C1_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "C2_MONTHLY": {
#             "label": "Chartered bank selected liabilities: Month-end",
#             "link": "https://www.bankofcanada.ca/valet/groups/C2_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "C3_MONTHLY": {
#             "label": "Historical chartered bank assets: Month-end",
#             "link": "https://www.bankofcanada.ca/valet/groups/C3_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "C4_MONTHLY": {
#             "label": "Historical chartered bank liabilities and shareholders",
#             "link": "https://www.bankofcanada.ca/valet/groups/C4_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "C8_MONTHLY": {
#             "label": "Historical chartered bank assets and liabilities: Selected seasonally adjusted series",
#             "link": "https://www.bankofcanada.ca/valet/groups/C8_MONTHLY",
#             "description": "Monthly average, Millions of dollars"
#         },
#         "C9_MONTHLY": {
#             "label": "Chartered banks: Total foreign currency assets and liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C9_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "F12_WEEKLY": {
#             "label": "Historical bond market trading by type of security",
#             "link": "https://www.bankofcanada.ca/valet/groups/F12_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "F13_WEEKLY": {
#             "label": "Historical Government of Canada treasury bill and bond trading with counterparties",
#             "link": "https://www.bankofcanada.ca/valet/groups/F13_WEEKLY",
#             "description": "Weekly Wednesday, Millions of dollars"
#         },
#         "F2_MONTHLY": {
#             "label": "Historical corporate and other short-term paper outstanding",
#             "link": "https://www.bankofcanada.ca/valet/groups/F2_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "K1_ANNUAL": {
#             "label": "Bank of Canada note liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/K1_ANNUAL",
#             "description": "As at 31 December, Thousands of dollars"
#         },
#         "G6_MONTHLY": {
#             "label": "Government of Canada direct securities and loans: Classified by remaining term to maturity and type of asset",
#             "link": "https://www.bankofcanada.ca/valet/groups/G6_MONTHLY",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "G7_MONTHLY": {
#             "label": "Government of Canada direct securities and loans: Holdings of general public classified by remaining term to maturity",
#             "link": "https://www.bankofcanada.ca/valet/groups/G7_MONTHLY",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_MONTHLY": {
#             "label": "Government of Canada bonds outstanding by currency of payments",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_MONTHLY",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "OFFICIAL_INT_RES": {
#             "label": "Official International Reserves",
#             "link": "https://www.bankofcanada.ca/valet/groups/OFFICIAL_INT_RES",
#             "description": "Millions in U.S. dollars"
#         },
#         "C5_QUARTERLY": {
#             "label": "Chartered banks: Regional distribution of selected assets",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_QUARTERLY",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C6_QUARTERLY": {
#             "label": "Chartered banks: Regional distribution of selected liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C6_QUARTERLY",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "SAN-2017-21": {
#             "label": "Staff Analytical Note - Evaluating real GDP growth forecasts in the Bank of Canada Monetary Policy Report",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN-2017-21",
#             "description": "This file contains data based on the Bank of Canada research paper described below. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the authors. The Bank is not responsible for errors in this file. The Bank and the authors do not guarantee that the series will be updated in the future. A contact person is listed below for any question or other inquiry.\nResearch Paper:\nEvaluating real GDP growth forecasts in the Bank of Canada Monetary Policy Report\nContact person:\nAndre Binette (abinette@bank-banque-canada.ca)\nDmitri Tchebotarev (dtchebotarev@bank-banque-canada.ca)"
#         },
#         "FSR-2017-NOVEMBER": {
#             "label": "November 2017 FSR",
#             "link": "https://www.bankofcanada.ca/valet/groups/FSR-2017-NOVEMBER",
#             "description": "November 2017 FSR"
#         },
#         "SLOS": {
#             "label": "Senior Loan Officer Survey",
#             "link": "https://www.bankofcanada.ca/valet/groups/SLOS",
#             "description": "The Senior Loan Officer Survey collects information on the business-lending practices of Canadian financial institutions. In particular, the Survey gathers the perspectives of respondents on price and non-price terms of business lending and on topical issues of interest to the Bank of Canada. The survey is conducted quarterly, near the end of the quarter for which the results are reported."
#         },
#         "C5_BN": {
#             "label": "Chartered banks: Regional distribution of selected assets - Bank notes and coin other than gold and silver bullion",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_BN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C5_SECURITIES": {
#             "label": "Chartered banks: Regional distribution of selected assets - Securities issued or guaranteed",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_SECURITIES",
#             "description": "Quarter-end, Millions of dollars\n"
#         },
#         "C5_MORTGAGES": {
#             "label": "Chartered banks: Regional distribution of selected assets - Mortgages",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_MORTGAGES",
#             "description": "Quarter-end, Millions of dollars\n"
#         },
#         "C5_NONMORTGAGELOANS": {
#             "label": "Chartered banks: Regional distribution of selected assets - Non-mortgage loans",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_NONMORTGAGELOANS",
#             "description": "Quarter-end, Millions of dollars\n"
#         },
#         "C5_LBE": {
#             "label": "Chartered banks: Regional distribution of selected assets - Land, building and equipment less accumulated depreciation",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_LBE",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C5_CUSTOMERSLIABILITY": {
#             "label": "Chartered banks: Regional distribution of selected assets - Customers' liability under acceptances",
#             "link": "https://www.bankofcanada.ca/valet/groups/C5_CUSTOMERSLIABILITY",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C6_PERSONAL": {
#             "label": "Chartered banks: Regional distribution of selected liabilities - Personal deposits",
#             "link": "https://www.bankofcanada.ca/valet/groups/C6_PERSONAL",
#             "description": "Quarter-end, Millions of dollars\n"
#         },
#         "C6_NONPERSONAL": {
#             "label": "Chartered banks: Regional distribution of selected liabilities - Non-personal deposits",
#             "link": "https://www.bankofcanada.ca/valet/groups/C6_NONPERSONAL",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C6_ACCEPTANCES": {
#             "label": "Chartered banks: Regional distribution of selected liabilities - Acceptances",
#             "link": "https://www.bankofcanada.ca/valet/groups/C6_ACCEPTANCES",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C6_LIABILITIES": {
#             "label": "Chartered banks: Regional distribution of selected liabilities - Liabilities of subsidiaries, other than deposits",
#             "link": "https://www.bankofcanada.ca/valet/groups/C6_LIABILITIES",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C6_NONCONTROLLING": {
#             "label": "Chartered banks: Regional distribution of selected liabilities - Non-controlling interests in subsidiaries",
#             "link": "https://www.bankofcanada.ca/valet/groups/C6_NONCONTROLLING",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "DELETE_ME": {
#             "label": "delete",
#             "link": "https://www.bankofcanada.ca/valet/groups/DELETE_ME",
#             "description": "delete"
#         },
#         "K8_CANADIAN": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Canadian dollars",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_CANADIAN",
#             "description": "Month-end, Millions of dollars (par value)\n"
#         },
#         "K8_TOTAL": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Total currencies",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_TOTAL",
#             "description": "Month-end, Millions of dollars (par value)\n"
#         },
#         "K9_MONTHLY": {
#             "label": "Historical net new issues of securities by corporations and federal government enterprises: Industrial classification",
#             "link": "https://www.bankofcanada.ca/valet/groups/K9_MONTHLY",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FOREIGN": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FOREIGN",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FC_USD": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies - United States dollars",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FC_USD",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FC_EURO": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies - Euro",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FC_EURO",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FC_SWISS": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies - Swiss francs",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FC_SWISS",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FC_POUND": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies - Pound sterling",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FC_POUND",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FC_JAPAN": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies - Japanese yen",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FC_JAPAN",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "K8_FC_OTHER": {
#             "label": "Government of Canada bonds outstanding by currency of payments - Foreign currencies - Other",
#             "link": "https://www.bankofcanada.ca/valet/groups/K8_FC_OTHER",
#             "description": "Month-end, Millions of dollars (par value)"
#         },
#         "C10_QUARTERLY": {
#             "label": "Chartered banks: Total claims and liabilities booked worldwide vis-à-vis non-residents",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_QUARTERLY",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "K12_QUARTERLY": {
#             "label": "Chartered banks: Classification of deposit liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/K12_QUARTERLY",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "B4_ANNUAL": {
#             "label": "Statistics pertaining to counterfeit Canadian bank notes",
#             "link": "https://www.bankofcanada.ca/valet/groups/B4_ANNUAL",
#             "description": "Annual"
#         },
#         "B4_QUARTERLY": {
#             "label": "Statistics pertaining to counterfeit Canadian bank notes ",
#             "link": "https://www.bankofcanada.ca/valet/groups/B4_QUARTERLY",
#             "description": "Quarterly"
#         },
#         "E1_MONTHLY": {
#             "label": "Selected monetary aggregates and their components",
#             "link": "https://www.bankofcanada.ca/valet/groups/E1_MONTHLY",
#             "description": "Month-end, Millions of dollars"
#         },
#         "F4F10_MONTHLY": {
#             "label": "Government of Canada debt securities: Gross new issues, retirements and net new issues",
#             "link": "https://www.bankofcanada.ca/valet/groups/F4F10_MONTHLY",
#             "description": "Monthly, Millions of dollars (par value)"
#         },
#         "E2_MONTHLY": {
#             "label": "Historical selected credit measures",
#             "link": "https://www.bankofcanada.ca/valet/groups/E2_MONTHLY",
#             "description": "Monthly average or average of month ends, Millions of dollars"
#         },
#         "C7_QUARTERLY": {
#             "label": "Chartered banks: Classification of non-mortgage loans",
#             "link": "https://www.bankofcanada.ca/valet/groups/C7_QUARTERLY",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C7_CANADIAN": {
#             "label": "Chartered banks: Classification of non-mortgage loans - Canadian dollar loans",
#             "link": "https://www.bankofcanada.ca/valet/groups/C7_CANADIAN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C7_FOREIGN": {
#             "label": "Chartered banks: Classification of non-mortgage loans - Foreign currency loans",
#             "link": "https://www.bankofcanada.ca/valet/groups/C7_FOREIGN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C7_GRAPH": {
#             "label": "Chartered banks: Classification of non-mortgage loans",
#             "link": "https://www.bankofcanada.ca/valet/groups/C7_GRAPH",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "K12_GRAPH": {
#             "label": "Chartered banks: Classification of deposit liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/K12_GRAPH",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "K12_CANADIAN": {
#             "label": "Chartered banks: Classification of deposit liabilities - Canadian dollar deposits",
#             "link": "https://www.bankofcanada.ca/valet/groups/K12_CANADIAN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "K12_FOREIGN": {
#             "label": "Chartered banks: Classification of deposit liabilities - Foreign currency deposits",
#             "link": "https://www.bankofcanada.ca/valet/groups/K12_FOREIGN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_TOTAL": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Total booked claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_TOTAL",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_US": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - United States claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_US",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_WESTERNEUR": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Western Europe claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_WESTERNEUR",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_CENTRALEUR": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Central Europe and Central Asia claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_CENTRALEUR",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_EASTASIA": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - East Asia and the Pacific claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_EASTASIA",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_LATINAMERICA": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Latin America and Caribbean claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_LATINAMERICA",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_NORTHAFRICA": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - North Africa and Middle East claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_NORTHAFRICA",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_SUBSAHARAN": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Sub-Saharan Africa claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_SUBSAHARAN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_OFFSHORE": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Offshore banking centers claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_OFFSHORE",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_UNALLOCATED": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Unallocated claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_UNALLOCATED",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_CLAIMS_FOREIGN": {
#             "label": "Chartered banks: Total claims booked worldwide vis-à-vis non-residents - Total claims on non-residents - Foreign currency on Canadian residents claims",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_CLAIMS_FOREIGN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_TOTAL": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Total booked liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_TOTAL",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_US": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - United States liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_US",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_WESTERNEUR": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Western Europe liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_WESTERNEUR",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_CENTRALEUR": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Central Europe and Central Asia liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_CENTRALEUR",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_EASTASIA": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - East Asia and the Pacific liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_EASTASIA",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_LATINAMERICA": {
#             "label": "Chartered banks: Total claims and liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Latin America and Caribbean liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_LATINAMERICA",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_NORTHAFRICA": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - North Africa and Middle East liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_NORTHAFRICA",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_OFFSHORE": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Offshore banking centers liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_OFFSHORE",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_SUBSAHARAN": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Sub-Saharan Africa liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_SUBSAHARAN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_UNALLOCATED": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Unallocated liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_UNALLOCATED",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "C10_LIABILITIES_FOREIGN": {
#             "label": "Chartered banks: Total liabilities booked worldwide vis-à-vis non-residents - Total liabilities to non-residents - Foreign currency on Canadian residents liabilities",
#             "link": "https://www.bankofcanada.ca/valet/groups/C10_LIABILITIES_FOREIGN",
#             "description": "Quarter-end, Millions of dollars"
#         },
#         "F4F10_CANADAABROAD": {
#             "label": "Government of Canada debt securities: Gross new issues, retirements and net new issues - Canada and abroad",
#             "link": "https://www.bankofcanada.ca/valet/groups/F4F10_CANADAABROAD",
#             "description": "Monthly, Millions of dollars (par value)"
#         },
#         "F4F10_CANADA": {
#             "label": "Government of Canada debt securities: Gross new issues, retirements and net new issues - Canada",
#             "link": "https://www.bankofcanada.ca/valet/groups/F4F10_CANADA",
#             "description": "Monthly, Millions of dollars (par value)"
#         },
#         "F4F10_ABROAD": {
#             "label": "Government of Canada debt securities: Gross new issues, retirements and net new issues - Abroad",
#             "link": "https://www.bankofcanada.ca/valet/groups/F4F10_ABROAD",
#             "description": "Monthly, Millions of dollars (par value)"
#         },
#         "F4F10_US": {
#             "label": "Government of Canada debt securities: Gross new issues, retirements and net new issues - United States",
#             "link": "https://www.bankofcanada.ca/valet/groups/F4F10_US",
#             "description": "Monthly, Millions of dollars (par value)"
#         },
#         "F4F10_OTHER": {
#             "label": "Government of Canada debt securities: Gross new issues, retirements and net new issues - Other countries",
#             "link": "https://www.bankofcanada.ca/valet/groups/F4F10_OTHER",
#             "description": "Monthly, Millions of dollars (par value)"
#         },
#         "SAN_LEBM180118": {
#             "label": "Is the Excess Bond Premium a Leading Indicator of Canadian Economic Activity?",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_LEBM180118",
#             "description": "This file contains data based on the Bank of Canada research paper described above. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future.\nSources:\nBloomberg Finance L.P., Bloomberg Finance L.P./Bank of America Merrill Lynch, Haver Analytics, Board of Governors of the Federal Reserve System and Bank of Canada calculations.\nNote from the author(s):\nDates for Chart 2 are arbitrary and not associated with any particular time period. It displays a hypothetical shock in 2018 and its associated responses over 3 subsequent years."
#         },
#         "SAN_LEBM180118_CHART1": {
#             "label": "Canadian excess bond premium is highly informative about the outlook for Canadian GDP",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_LEBM180118_CHART1",
#             "description": "This file contains data based on the Bank of Canada research paper described above. The data is not an official statistical release by the Bank of Canada, and it is provided on a voluntary basis by the author(s). The Bank and the author(s) are not responsible for errors in this file and do not guarantee that the series will be updated in the future.\nSources:\nBloomberg Finance L.P., Bloomberg Finance L.P./Bank of America Merrill Lynch, Haver Analytics, Board of Governors of the Federal Reserve System and Bank of Canada calculations."
#         },
#         "SAN_LEBM180118_CHART2A": {
#             "label": "Real GDP",
# ...
#             "description": "Tattle-tails: Gauging downside risks using option prices"
#         },
#         "SAN_TUPI20230830_C2": {
#             "label": "Chart 2: The stock prices of global banks declined through the stress period",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_TUPI20230830_C2",
#             "description": "Bank equities, index: March 6, 2023 = 100\n\nNote: “Canada—domestic systemically important banks” is the unweighted average of the equity prices of the following six banks: Bank of Montreal, Bank of Nova Scotia, Canadian Imperial Bank of Commerce, National Bank of Canada, Royal Bank of Canada and Toronto-Dominion Bank. “Canada—small and medium-sized deposit-taking institutions” is the unweighted average of the equity prices of the following three banks: EQB Inc., Canadian Western Bank and Laurentian Bank of Canada. “United States—global systemically important banks” is the unweighted average of the equity prices of the following eight banks: Bank of America Corporation, Citigroup Inc, Goldman Sachs Group Inc, JPMorgan Chase & Co., Morgan Stanley, State Street Corporation, The Bank of New York Mellon Corporation and Wells Fargo & Company\n\nBloomberg Finance L.P."
#         },
#         "SAN_TUPI20230830_C3": {
#             "label": "Chart 3: The financial system stress increased uncertainty and downside risks to Canadian interest rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_TUPI20230830_C3",
#             "description": "XSB option-implied probability; expiry: September 15, 2023\n\nFor ease of interpretation, we present the x-axis of all equity exchange-traded funds as a share price but convert the price of XSB to an interest rate.\n\nTMX Montréal Exchange, Bloomberg Finance L.P. and Bank of Canada calculations"
#         },
#         "SAN_TUPI20230830_C4": {
#             "label": "Chart 4: Declines in Canadian bank stocks and downside risks were not consistent with risks of a domestic banking sector stress",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_TUPI20230830_C4",
#             "description": "ZEB option-implied probability; expiry: September 15, 2023\n\nTMX Montréal Exchange, Bloomberg Finance L.P. and Bank of Canada calculations"
#         },
#         "SAN_TUPI20230830_C5": {
#             "label": "Chart 5: The stress created minimal downside risks for broad Canadian economic growth",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_TUPI20230830_C5",
#             "description": "XIU option-implied probability; expiry: September 15, 2023\n\nTMX Montréal Exchange, Bloomberg Finance L.P. and Bank of Canada calculations"
#         },
#         "SAN_TUPI20230830_C1": {
#             "label": "Chart 1: Government bond yields in Canada and around the world declined sharply",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_TUPI20230830_C1",
#             "description": "Change in nominal yields of 2-year bonds since March 6, 2023\n\nSource: Bloomberg Finance L.P."
#         },
#         "SAN_CHAN20230905": {
#             "label": "Three things we learned about the Lynx payment system",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHAN20230905",
#             "description": "Three things we learned about the Lynx payment system"
#         },
#         "SAN_CHAN20230905_C1A": {
#             "label": "Value",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHAN20230905_C1A",
#             "description": "System-level daily average values and volumes of payments settled in LVTS and Lynx, weekly average"
#         },
#         "SAN_CHAN20230905_C1B": {
#             "label": "Volume",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHAN20230905_C1B",
#             "description": ""
#         },
#         "SAN_CHAN20230905_C3": {
#             "label": "Lynx provided more liquidity efficiency than the LVTS",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHAN20230905_C3",
#             "description": ""
#         },
#         "SAN_CHAN20230905_C2": {
#             "label": "Payments arrived earlier in Lynx than in the LVTS",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHAN20230905_C2",
#             "description": ""
#         },
#         "BOS_2023Q3": {
#             "label": "BOS 2023Q3",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3",
#             "description": "BOS 2023Q3"
#         },
#         "BOS_2023Q3_C1": {
#             "label": "The BOS indicator has declined further",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C1",
#             "description": "Contributions to BOS indicator (standardized units)\n\nThe BOS indicator is a summary measure of the main Business Outlook Survey (BOS) questions. Business activity indicators are those related to past sales declines, future sales growth, indicators of future sales, employment and investment. Price and cost indicators are those related to input and output price growth as well as credit conditions. Capacity indicators are those related to labour shortages, labour shortage intensity and the ability to meet demand. The calculation of the BOS indicator has changed, effective in the first quarter of 2023. A backgrounder outlining the motivation for and implications of the change was published on the Bank’s website on May 8, 2023."
#         },
#         "BOS_2023Q3_C2": {
#             "label": "Concerns about slowing demand continue to rise",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C2",
#             "description": "In the current quarter, which items have been the most pressing concerns for your company? Select up to three. (Share of firms)\n\nThis question in the Business Leaders' Pulse is typically asked only one month in each quarter. The question was not asked in any month during the third quarter of 2022.\n\nBusiness Leaders’ Pulse"
#         },
#         "BOS_2023Q3_C3": {
#             "label": "Firms still plan to raise prices more than normal",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C3",
#             "description": "Size of price changes (balance of opinion*): Over the past 12 months (next 12 months), on average across the products and services you sell, the size of your price changes, in percent, has been (will be): larger than normal, smaller than normal or roughly the same size as normal. Frequency of price changes (balance of opinion†): Over the past 12 months (next 12 months), on average across the products and services you sell, how often have you changed (will you change) selling prices: more frequently than normal, less frequently than normal or as frequently as normal?\n\n* Percentage of firms experiencing or expecting larger-than-normal price increases minus the percentage experiencing or expecting smaller-than-normal price increases\n† Percentage of firms experiencing or expecting more-frequent-than-normal price increases minus the percentage experiencing or expecting less-frequent-than-normal price increases. Firms without regular pricing frequency were excluded.\n\nBusiness Leader’s Pulse"
#         },
#         "BOS_2023Q3_C5": {
#             "label": "The negative impacts of higher rates are widespread",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C5",
#             "description": "Since March of last year, the Bank has raised the target for the overnight rate to 5.00%.  What impacts, if any, do you see from these interest rate increases on your business operations or decisions? (Share of firms negatively impacted by interest rates, grouped by sector)"
#         },
#         "BOS_2023Q3_C6": {
#             "label": "Firms believe the impacts of tightened monetary policy are just beginning",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C6",
#             "description": "Interest rates in Canada have risen since 2021. How would you categorize the impacts these interest rate increases have had so far on your business?\n\nBusiness Leader’s Pulse"
#         },
#         "BOS_2023Q3_C10": {
#             "label": "Firms' short-term inflation expectations eased down further",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C10",
#             "description": "BOS estimate: Over the next two years, what do you expect the annual rate of inflation to be, based on the consumer price index? BLP estimates: What do you expect the rate of annual inflation to be in about one, two and five years from now?\n\nBLP is the Business Leaders' Pulse and BOS is the Business Outlook Survey. In the BOS, firms can select from predetermined ranges and also provide a point estimate.\n In a subset of cases, firms provide a range only, which can be closed or open. If the range is closed, we use the midpoint of the range. If the range is open, we use the average expectation of other firms in that range. The value for each quarter is the trimmed mean, excluding the two highest and two lowest responses. In the \nBLP, firms can select from predetermined ranges, which can be open or closed. We use the midpoints of the closed ranges. We assign a value of -1% to responses in the lowest open-ended range (“deflation”) and 9% to responses in the highest open-ended range (“8% or higher”). This question was not asked in the January or March 2022 BLP."
#         },
#         "BOS_2023Q3_C4": {
#             "label": "Firms' sales outlooks remain weak",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C4",
#             "description": "Indicators of future sales (balance of opinion*): Compared with 12 months ago, have your recent indicators (order books, advance bookings, sales inquiries, etc.) improved, deteriorated or remained the same?"
#         },
#         "BOS_2023Q3_C8": {
#             "label": "Labour market pressures continue to ease",
#             "link": "https://www.bankofcanada.ca/valet/groups/BOS_2023Q3_C8",
#             "description": "Labour shortages: Does your firm face any shortages of labour that restrict your ability to meet demand? Intensity of labour shortages (balance of opinion*): Compared with 12 months ago, are labour shortages generally more intense, less intense or about the same intensity?\n\n* Percentage of firms reporting more-intense labour shortages minus the percentage reporting less-intense shortages"
#         },
#         "CSCE_2023Q3": {
#             "label": "CSCE 2023Q3",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3",
#             "description": "CSCE 2023Q3"
#         },
#         "CSCE_2023Q3_C2": {
#             "label": "Most people understand that the Bank raised interest rates to reduce inflation, but less than half expect it will work",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C2",
#             "description": "For those who think the Bank of Canada recently raised rates: In your view, what does the Bank aim to achieve by increasing rates? In your view, how will this action affect the inflation rate?"
#         },
#         "CSCE_2023Q3_C3": {
#             "label": "Most people are reducing spending to guard against inflation",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C3",
#             "description": "What actions are you taking to protect yourself against inflation?"
#         },
#         "CSCE_2023Q3_C4": {
#             "label": "The impacts of higher interest rates have broadened",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C4",
#             "description": "Were you financially impacted by recent increases in interest rates by the Bank of Canada? Did you become better off or worse off as a result?"
#         },
#         "CSCE_2023Q3_C5": {
#             "label": "Many homeowners’ mortgage payments are close to or beyond the maximum they can afford",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C5",
#             "description": "How much is your regular mortgage payment? Based on your current financial situation, what is the maximum regular mortgage payment you feel you can afford?\n\nThe ratio represents the maximum affordable amount divided by the current mortgage payment. A ratio above 1 implies that the mortgage holder can afford a higher payment, while a ratio below 1 implies that the mortgage payment is above what the mortgage holder believes is affordable."
#         },
#         "CSCE_2023Q3_C7": {
#             "label": "Many consumers expect further impacts from higher interest rates",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C7",
#             "description": "Interest rates in Canada have risen since 2021. How would you categorize the impact these interest rate increases have had so far on your household spending?"
#         },
#         "CSCE_2023Q3_C8": {
#             "label": "Plans for making major purchases are more widespread for services than for goods",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C8",
#             "description": "Did you make any major purchases (excluding homes or financial investments) in the past six months? Do you plan to make any major purchases (excluding homes or financial investments) in the next six months?"
#         },
#         "CSCE_2023Q3_C10": {
#             "label": "The share of people who reported working more hours now than last year has decreased",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C10",
#             "description": "You said you have worked __ hours in the previous week. How does this compare with the same time last year?"
#         },
#         "CSCE_2023Q3_C6": {
#             "label": "Housing market expectations eased slightly despite strong demand from newcomers",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C6",
#             "description": "What is the likelihood that over the next 12 months you will: move to a different primary residence? Put your primary residence on the market for sale? Are you planning to buy or thinking of buying a house or condo now?"
#         },
#         "CSCE_2023Q3_C1": {
#             "label": "Elevated perceptions of current inflation are leading to persistently high near-term inflation expectations",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C1",
#             "description": "Inflation expectation for each horizon: What do you expect the rate of inflation (deflation) to be?  Perceptions about current inflation: What do you think the rate of inflation (deflation) was over the last 12 months?"
#         },
#         "CSCE_2023Q3_C1A": {
#             "label": "The gap between perceived and actual inflation is particularly high for young consumers",
#             "link": "https://www.bankofcanada.ca/valet/groups/CSCE_2023Q3_C1A",
#             "description": "Difference between perceived inflation and consumer price index inflation (percentage points)"
#         },
#         "SAN_CHIU20230823": {
#             "label": "Decentralized  finance: Innovations and challenges",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHIU20230823",
#             "description": "Decentralized  finance: Innovations and challenges"
#         },
#         "SAN_CHIU20230823_C1": {
#             "label": "Total value locked in decentralized finance on Ethereum",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHIU20230823_C1",
#             "description": "Source: DefiLlama"
#         },
#         "SAN_CHIU20230823_C2": {
#             "label": "Composition of Ethereum’s decentralized finance services",
#             "link": "https://www.bankofcanada.ca/valet/groups/SAN_CHIU20230823_C2",
#             "description": "Liquid staking is a DeFi investment service that allows users to pledge their funds to earn staking rewards, but the investment remains liquid in the sense that users can still access a tokenized version of their funds.\n\nSource: DeFiLlama"
#         }    }
# }

# %% [raw]
# REF_CPI_DATE,"Real Return Bonds - Ref CPI","Real Return Bonds - Ref CPI",https://www.bankofcanada.ca/valet/series/REF_CPI_DATE
#
# INDEX_RATIO_2021,"Real Return Bonds - Index ratio 2021","Real Return Bonds - Index ratio 2021",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2021
# INDEX_RATIO_2026,"Real Return Bonds - Index ratio 2026","Real Return Bonds - Index ratio 2026",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2026
# INDEX_RATIO_2031,"Real Return Bonds - Index ratio 2031","Real Return Bonds - Index ratio 2031",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2031
# INDEX_RATIO_2036,"Real Return Bonds - Index ratio 2036","Real Return Bonds - Index ratio 2036",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2036
# INDEX_RATIO_2041,"Real Return Bonds - Index ratio 2041","Real Return Bonds - Index ratio 2041",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2041
# INDEX_RATIO_2044,"Real Return Bonds - Index ratio 2044","Real Return Bonds - Index ratio 2044",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2044
# INDEX_RATIO_2047,"Real Return Bonds - Index ratio 2047","Real Return Bonds - Index ratio 2047",https://www.bankofcanada.ca/valet/series/INDEX_RATIO_2047
#
# V41690973,"Total CPI","Total CPI",https://www.bankofcanada.ca/valet/series/V41690973
# V41690914,"Total CPI, (seasonally adjusted)","Total CPI, (seasonally adjusted)",https://www.bankofcanada.ca/valet/series/V41690914
# V41693242,"Core CPI","Core CPI",https://www.bankofcanada.ca/valet/series/V41693242
#
# STATIC_INFLATIONCALC,"Total CPI","Total CPI",https://www.bankofcanada.ca/valet/series/STATIC_INFLATIONCALC
#
# SWP_FEUN_20160726_01,"Canadian CPI expected inflation over the next two years - Annual Percentage","Canadian CPI expected inflation over the next two years - Annual Percentage",https://www.bankofcanada.ca/valet/series/SWP_FEUN_20160726_01
# SWP_FEUN_20160726_02,"Canadian inflation risk premium over the next two years - Annual Percentage","Canadian inflation risk premium over the next two years - Annual Percentage",https://www.bankofcanada.ca/valet/series/SWP_FEUN_20160726_02
#
# V122495,"V122495","Prime rate",https://www.bankofcanada.ca/valet/series/V122495
#
# BMTGOCRR.DALL,"Real Return Bonds","Government of Canada bonds",https://www.bankofcanada.ca/valet/series/BMTGOCRR.DALL
